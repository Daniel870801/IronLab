# %%
pip install stackAPI
# Out:
# ...
#   Created wheel for stackAPI: filename=StackAPI-0.2.0-py3-none-any.whl size=5856 sha256=f3679bdb69a826f555f898850723d4d189223c9e1cda381a033898c8c29d23ac
#   Stored in directory: /Users/helmichaaba/Library/Caches/pip/wheels/de/58/fe/8bab7cf44d8b0bf32e46f1715df2ba8c97d475de95a20985ac
# Successfully built stackAPI
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from stackapi import StackAPI

# %%
SITE = StackAPI('stackoverflow')
comments = SITE.fetch('comments')
comments
# Out:
# {'backoff': 0,
#  'has_more': True,
#  'page': 5,
#  'quota_max': 300,
#  'quota_remaining': 115,
#  'total': 0,
#  'items': [{'owner': {'reputation': 115557,
#     'user_id': 1136211,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/ecd80cd7d5927902f3af471fa0353836?s=256&d=identicon&r=PG',
#     'display_name': 'Clemens',
#     'link': 'https://stackoverflow.com/users/1136211/clemens'},
#    'edited': False,
#    'score': 0,
#    'creation_date': 1646151407,
#    'post_id': 71310786,
#    'comment_id': 126050175,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 488856,
#     'user_id': 20860,
#     'user_type': 'registered',
#     'accept_rate': 92,
#     'profile_image': 'https://i.stack.imgur.com/iavmP.jpg?s=256&g=1',
#     'display_name': 'Bill Karwin',
#     'link': 'https://stackoverflow.com/users/20860/bill-karwin'},
#    'edited': False,
#    'score': 0,
#    'creation_date': 1646151405,
#    'post_id': 71311407,
# ...

# %%
#Question__1

# %%
SITE = StackAPI('stackoverflow')
questions = SITE.fetch('questions', fromdate=1643732204, todate=1646151404,
min=10, tagged='python', sort='votes')
questions
# Out:
# {'backoff': 0,
#  'has_more': False,
#  'page': 1,
#  'quota_max': 300,
#  'quota_remaining': 31,
#  'total': 0,
#  'items': [{'tags': ['python', 'list', 'list-comprehension'],
#    'owner': {'reputation': 351,
#     'user_id': 6457716,
#     'user_type': 'registered',
#     'accept_rate': 75,
#     'profile_image': 'https://www.gravatar.com/avatar/aa5129ffe5bd5ab0897331fb0a298448?s=256&d=identicon&r=PG&f=1',
#     'display_name': 'cinderashes',
#     'link': 'https://stackoverflow.com/users/6457716/cinderashes'},
#    'is_answered': True,
#    'view_count': 2278,
#    'accepted_answer_id': 70965024,
#    'answer_count': 6,
#    'score': 23,
#    'last_activity_date': 1645651964,
#    'creation_date': 1643851944,
#    'last_edit_date': 1643902809,
#    'question_id': 70964954,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/70964954/filter-out-everything-before-a-condition-is-met-keep-all-elements-after',
# ...

# %%
answers = SITE.fetch('answers', fromdate=1643732204, todate=1646151404,
min=10, tagged='python', sort='votes')
answers
# Out:
# {'backoff': 0,
#  'has_more': False,
#  'page': 1,
#  'quota_max': 300,
#  'quota_remaining': 22,
#  'total': 0,
#  'items': [{'owner': {'reputation': 29963,
#     'user_id': 1086121,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/85d145ca3d7f8490da86055b72f3d859?s=256&d=identicon&r=PG',
#     'display_name': 'canton7',
#     'link': 'https://stackoverflow.com/users/1086121/canton7'},
#    'is_accepted': True,
#    'score': 92,
#    'last_activity_date': 1645274143,
#    'last_edit_date': 1645274143,
#    'creation_date': 1644490416,
#    'answer_id': 71063828,
#    'question_id': 71063730,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 212054,
#     'user_id': 2079303,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/6cf7f63e49a75376e0f761c8abeb6d5a?s=256&d=identicon&r=PG',
#     'display_name': 'eerorika',
#     'link': 'https://stackoverflow.com/users/2079303/eerorika'},
# ...

# %%
#QUESTION__2: Find the most voted question today with at least a score of 5 and tagged with 'python'.

# %%
SITE = StackAPI('stackoverflow')
questions = SITE.fetch('questions', fromdate=1646151998, todate=1646151998,
min=5, tagged='python', sort='votes')
questions
# Out:
# {'backoff': 0,
#  'has_more': False,
#  'page': 1,
#  'quota_max': 300,
#  'quota_remaining': 13,
#  'total': 0,
#  'items': []}

# %%
#QUESTION__3: Find the answers with id 6784 and 6473.

# %%
SITE = StackAPI("stackoverflow")
badges = SITE.fetch('badges',ids=[6784,6473])
badges
# Out:
# {'backoff': 0,
#  'has_more': False,
#  'page': 1,
#  'quota_max': 300,
#  'quota_remaining': 11,
#  'total': 0,
#  'items': [{'badge_type': 'tag_based',
#    'award_count': 1,
#    'rank': 'silver',
#    'badge_id': 6784,
#    'link': 'https://stackoverflow.com/badges/6784/asterisk',
#    'name': 'asterisk'},
#   {'badge_type': 'tag_based',
#    'award_count': 1,
#    'rank': 'gold',
#    'badge_id': 6473,
#    'link': 'https://stackoverflow.com/badges/6473/sql-server-2012',
#    'name': 'sql-server-2012'}]}
